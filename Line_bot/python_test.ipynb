# %%
name = "sam"
avg = 50
weight = 105.8
height = 182.4
man = True
print(name)
print(avg)
print(weight)
print(height)
print(man)
add = weight + height
print(f"hi : {name}, you old : {avg} , you weight : {weight} add : {add}")
# Out:
# sam
# 50
# 105.8
# 182.4
# True
# hi : sam, you old : 50 , you weight : 105.8
